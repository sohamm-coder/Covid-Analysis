# %%
##Importing data from github
import pandas as pd
import requests
import io
import plotly.express as px
import matplotlib.pyplot as plt
import numpy as np

url = "https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv"
download = requests.get(url).content

data = pd.read_csv(io.StringIO(download.decode('utf-8')),error_bad_lines=False,sep=',',engine='python')

# %%
#print(type(download))
usecols=['continent','location','date','total_cases','new_cases','total_deaths','new_deaths',
         'icu_patients','total_vaccinations','reproduction_rate','new_tests','total_tests','total_vaccinations',
         'people_vaccinated','population','population_density','median_age','aged_65_older','gdp_per_capita',
        'male_smokers','female_smokers','extreme_poverty','life_expectancy',
         'diabetes_prevalence','cardiovasc_death_rate','handwashing_facilities','human_development_index']
data[usecols]

# counter = 0
# data = pd.DataFrame()
# for row in download.decode("utf-8").split("\n"):
#      print(row)
#      counter += 1
#      if counter > 6:
#         break
    
#     data_raw = pd.read_csv(row,)
# Out:
#       continent     location        date  total_cases  new_cases  \
# 0          Asia  Afghanistan  2020-02-24          1.0        1.0
# 1          Asia  Afghanistan  2020-02-25          1.0        0.0
# 2          Asia  Afghanistan  2020-02-26          1.0        0.0
# 3          Asia  Afghanistan  2020-02-27          1.0        0.0
# 4          Asia  Afghanistan  2020-02-28          1.0        0.0
# ...         ...          ...         ...          ...        ...
# 83857    Africa     Zimbabwe  2021-04-20      37875.0       16.0
# 83858    Africa     Zimbabwe  2021-04-21      37980.0      105.0
# 83859    Africa     Zimbabwe  2021-04-22      38018.0       38.0
# 83860    Africa     Zimbabwe  2021-04-23      38045.0       27.0
# 83861    Africa     Zimbabwe  2021-04-24      38064.0       19.0
#
#        total_deaths  new_deaths  icu_patients  total_vaccinations  \
# 0               NaN         NaN           NaN                 NaN
# ...

# %%
india_cases = data[data['location'].str.contains('India')]
print(contain_values)
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 34479      IND      Asia    India  2020-01-30          1.0        1.0
# 34480      IND      Asia    India  2020-01-31          1.0        0.0
# 34481      IND      Asia    India  2020-02-01          1.0        0.0
# 34482      IND      Asia    India  2020-02-02          2.0        1.0
# 34483      IND      Asia    India  2020-02-03          3.0        1.0
# ...        ...       ...      ...         ...          ...        ...
# 34925      IND      Asia    India  2021-04-20   15616130.0   295158.0
# 34926      IND      Asia    India  2021-04-21   15930774.0   314644.0
# 34927      IND      Asia    India  2021-04-22   16263695.0   332921.0
# 34928      IND      Asia    India  2021-04-23   16610481.0   346786.0
# 34929      IND      Asia    India  2021-04-24   16960172.0   349691.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
fig = px.bar(india_cases , x='date', y='total_cases',title ='Cases in India')
fig.show()
# Out:
# <div>                            <div id="1cdec382-4dd9-41f0-874e-6b24674cc2ab" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1cdec382-4dd9-41f0-874e-6b24674cc2ab")) {                    Plotly.newPlot(                        "1cdec382-4dd9-41f0-874e-6b24674cc2ab",                        [{"alignmentgroup": "True", "hovertemplate": "date=%{x}<br>total_cases=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["2020-01-30", "2020-01-31", "2020-02-01", "2020-02-02", "2020-02-03", "2020-02-04", "2020-02-05", "2020-02-06", "2020-02-07", "2020-02-08", "2020-02-09", "2020-02-10", "2020-02-11", "2020-02-12", "2020-02-13
# ...

# %%
    fig = px.bar(india_cases , x='date', y='new_cases',title ='Daily Cases')
fig.show()
# Out:
# <div>                            <div id="4c4c039e-0dcb-4573-afce-8341fcf77468" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4c4c039e-0dcb-4573-afce-8341fcf77468")) {                    Plotly.newPlot(                        "4c4c039e-0dcb-4573-afce-8341fcf77468",                        [{"alignmentgroup": "True", "hovertemplate": "date=%{x}<br>new_cases=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["2020-01-30", "2020-01-31", "2020-02-01", "2020-02-02", "2020-02-03", "2020-02-04", "2020-02-05", "2020-02-06", "2020-02-07", "2020-02-08", "2020-02-09", "2020-02-10", "2020-02-11", "2020-02-12", "2020-02-13",
# ...

# %%
fig = px.bar(india_cases , x='date', y='total_vaccinations',title ='Vaccination')
fig.show()
# Out:
# <div>                            <div id="07d53ed4-39db-4271-9d28-7c7d38096c80" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("07d53ed4-39db-4271-9d28-7c7d38096c80")) {                    Plotly.newPlot(                        "07d53ed4-39db-4271-9d28-7c7d38096c80",                        [{"alignmentgroup": "True", "hovertemplate": "date=%{x}<br>total_vaccinations=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["2020-01-30", "2020-01-31", "2020-02-01", "2020-02-02", "2020-02-03", "2020-02-04", "2020-02-05", "2020-02-06", "2020-02-07", "2020-02-08", "2020-02-09", "2020-02-10", "2020-02-11", "2020-02-12", "202
# ...

# %%
fig = px.bar(india_cases , x='date', y='new_deaths',title ='New Deaths')
fig.show()
# Out:
# <div>                            <div id="bb301abe-ed84-4dfd-8494-3c69ffc96838" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bb301abe-ed84-4dfd-8494-3c69ffc96838")) {                    Plotly.newPlot(                        "bb301abe-ed84-4dfd-8494-3c69ffc96838",                        [{"alignmentgroup": "True", "hovertemplate": "date=%{x}<br>new_deaths=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["2020-01-30", "2020-01-31", "2020-02-01", "2020-02-02", "2020-02-03", "2020-02-04", "2020-02-05", "2020-02-06", "2020-02-07", "2020-02-08", "2020-02-09", "2020-02-10", "2020-02-11", "2020-02-12", "2020-02-13"
# ...

# %%
fig = px.bar(india_cases , x='date', y='total_deaths',title ='Total deaths')
fig.show()
# Out:
# <div>                            <div id="31e09090-777b-4ce2-8b26-aa659a226735" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("31e09090-777b-4ce2-8b26-aa659a226735")) {                    Plotly.newPlot(                        "31e09090-777b-4ce2-8b26-aa659a226735",                        [{"alignmentgroup": "True", "hovertemplate": "date=%{x}<br>total_deaths=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["2020-01-30", "2020-01-31", "2020-02-01", "2020-02-02", "2020-02-03", "2020-02-04", "2020-02-05", "2020-02-06", "2020-02-07", "2020-02-08", "2020-02-09", "2020-02-10", "2020-02-11", "2020-02-12", "2020-02-1
# ...

# %%
fig = px.scatter(data, x="gdp_per_capita", y="extreme_poverty",
	         size="total_cases", color="continent",
                 hover_name="location")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-96149dc5ff32> in <module>
# ----> 1 fig = px.scatter(data, x="gdp_per_capita", y="extreme_poverty",
#       2                  size="total_cases", color="continent",
#       3                  hover_name="location")
#       4 fig.show()
#
# ...
